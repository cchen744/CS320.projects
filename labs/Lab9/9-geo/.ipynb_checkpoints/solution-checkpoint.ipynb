# %% [markdown]
# # Background
#
# ## Goal
#
# Say you want to advertise to nearby residents for this grocery store: https://freshmadisonmarket.com/.  You want to create a map like this to identify these potential customers:

# %%
from IPython.display import Image
Image(filename='expected.png')

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
plt.rcParams["font.size"] = 16

# %%
# %matplotlib inline

# %%
city = gpd.read_file("zip://city.zip")
lakes = gpd.read_file("zip://lakes.zip")
street = gpd.read_file("zip://street.zip")

# %%
city.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# BUG 1: why isn't it finding the one on the corner of University and N Lake Street?
fresh = gpd.tools.geocode("The Fresh Market; Madison, WI")
fresh
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:446, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442         except BaseException as e:
#     443             # Remove the TypeError from the exception chain in
#     444             # Python 3 (including for exceptions like SystemExit).
#     445             # Otherwise it looks like a bug in the code.
# --> 446             six.raise_from(e, None)
#     447 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:441, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     440 try:
# --> 441     httplib_response = conn.getresponse()
# ...

# %%
def plot_background():
    ax = city.plot(color="lightgray", alpha=.2, figsize=(12, 12), zorder=2)
    lakes.plot(color="lightblue", ax=ax, zorder=1, alpha=0.8)
    street.plot(color="darkgray", alpha = .5, ax=ax, zorder=3)
    ax.set_axis_off()
    return ax

# %%
# BUG 2: why is it complaining we didn't do to_crs, when we did?
fresh = fresh.to_crs("epsg:32616") # reproject to meters
fresh.geometry = fresh.geometry.buffer(2000)
fresh = fresh.to_crs(city.crs) # reproject back to lat, lon for plotting

# %%
# BUG 3: why isn't it only highlighting land near the grocery store?
ax = plot_background()
fresh.union(city.unary_union).plot(color="#ffbfba", ax=ax)
# Out:
# /tmp/ipykernel_466152/2299391021.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   fresh.union(city.unary_union).plot(color="#ffbfba", ax=ax)
# <Axes: >
