# %%
import pandas as pd
import sqlite3

df = pd.DataFrame([
    {"state": "wi", "city": "madison", "address": "123 Main St.", "item": "apples", "quantity": 3, "price": 1},
    {"state": "wi", "city": "madison", "address": "123 Main St.", "item": "oranges", "quantity": 4, "price": 0.8},
    {"state": "wi", "city": "madison", "address": "123 Main St.", "item": "cantaloupe", "quantity": 5, "price": 2},
    {"state": "wi", "city": "milwaukee", "address": "456 State St", "item": "apples", "quantity": 6, "price": 0.9},
    {"state": "wi", "city": "milwaukee", "address": "456 State St.", "item": "oranges", "quantity": 8, "price": 1.2},
])
connection = sqlite3.connect("grocery.db")
df.to_sql("sales", connection, if_exists="replace", index=False)
# Out:
# 5

# %%
pd.read_sql("SELECT * FROM sales", connection)
# Out:
#   state       city        address        item  quantity  price
# 0    wi    madison   123 Main St.      apples         3    1.0
# 1    wi    madison   123 Main St.     oranges         4    0.8
# 2    wi    madison   123 Main St.  cantaloupe         5    2.0
# 3    wi  milwaukee   456 State St      apples         6    0.9
# 4    wi  milwaukee  456 State St.     oranges         8    1.2

# %%
pd.read_sql("SELECT item, SUM(quantity*price) AS dollars FROM sales GROUP BY item", connection)
# Out:
#          item  dollars
# 0      apples      8.4
# 1  cantaloupe     10.0
# 2     oranges     12.8

# %%
 pd.read_sql("SELECT state, city, address, SUM(quantity*price) AS dollars FROM sales GROUP BY state, city, address", connection)
# Out:
#   state       city        address  dollars
# 0    wi    madison   123 Main St.     16.2
# 1    wi  milwaukee   456 State St      5.4
# 2    wi  milwaukee  456 State St.      9.6

# %%
f = pd.DataFrame([
    {"location_id": 1, "state": "wi", "city": "madison", "address": "123 Main St."},
    {"location_id": 2, "state": "wi", "city": "milwaukee", "address": "456 State St."},
])
df.to_sql("locations", connection, if_exists="replace", index=False)

df = pd.DataFrame([
    {"location_id": 1, "item": "apples", "quantity": 3, "price": 1},
    {"location_id": 1, "item": "oranges", "quantity": 4, "price": 0.8},
    {"location_id": 1, "item": "cantaloupe", "quantity": 5, "price": 2},
    {"location_id": 2, "item": "apples", "quantity": 6, "price": 0.9},
    {"location_id": 2, "item": "oranges", "quantity": 8, "price": 1.2},
])

df.to_sql("sales", connection, if_exists="replace", index=False)
# Out:
# 5

# %%
pd.read_sql("SELECT * FROM sales", connection)
# Out:
#    location_id        item  quantity  price
# 0            1      apples         3    1.0
# 1            1     oranges         4    0.8
# 2            1  cantaloupe         5    2.0
# 3            2      apples         6    0.9
# 4            2     oranges         8    1.2

# %%
pd.read_sql("SELECT * FROM locations", connection)
# Out:
#    location_id        item  quantity  price
# 0            1      apples         3    1.0
# 1            1     oranges         4    0.8
# 2            1  cantaloupe         5    2.0
# 3            2      apples         6    0.9
# 4            2     oranges         8    1.2

# %%
pd.read_sql("SELECT * FROM locations INNER JOIN sales", connection)
# Out:
#     location_id        item  quantity  price  location_id        item  \
# 0             1      apples         3    1.0            1      apples
# 1             1      apples         3    1.0            1     oranges
# 2             1      apples         3    1.0            1  cantaloupe
# 3             1      apples         3    1.0            2      apples
# 4             1      apples         3    1.0            2     oranges
# 5             1     oranges         4    0.8            1      apples
# 6             1     oranges         4    0.8            1     oranges
# 7             1     oranges         4    0.8            1  cantaloupe
# 8             1     oranges         4    0.8            2      apples
# 9             1     oranges         4    0.8            2     oranges
# 10            1  cantaloupe         5    2.0            1      apples
# 11            1  cantaloupe         5    2.0            1     oranges
# 12            1  cantaloupe         5    2.0            1  cantaloupe
# 13            1  cantaloupe         5    2.0            2      apples
# 14            1  cantaloupe         5    2.0            2     oranges
# 15            2      apples         6    0.9            1      apples
# 16            2      apples         6    0.9            1     oranges
# 17            2      apples         6    0.9            1  cantaloupe
# 18            2      apples         6    0.9            2      apples
# 19            2      apples         6    0.9            2     oranges
# 20            2     oranges         8    1.2            1      apples
# 21            2     oranges         8    1.2            1     oranges
# 22            2     oranges         8    1.2            1  cantaloupe
# 23            2     oranges         8    1.2            2      apples
# 24            2     oranges         8    1.2            2     oranges
#
#     quantity  price
# 0          3    1.0
# 1          4    0.8
# 2          5    2.0
# 3          6    0.9
# 4          8    1.2
# 5          3    1.0
# 6          4    0.8
# 7          5    2.0
# 8          6    0.9
# 9          8    1.2
# 10         3    1.0
# 11         4    0.8
# 12         5    2.0
# 13         6    0.9
# 14         8    1.2
# 15         3    1.0
# 16         4    0.8
# 17         5    2.0
# 18         6    0.9
# 19         8    1.2
# 20         3    1.0
# 21         4    0.8
# 22         5    2.0
# 23         6    0.9
# 24         8    1.2

# %%
pd.read_sql("SELECT * FROM locations INNER JOIN sales ON locations.location_id = sales.location_id", connection)
# Out:
#     location_id        item  quantity  price  location_id        item  \
# 0             1      apples         3    1.0            1      apples
# 1             1      apples         3    1.0            1  cantaloupe
# 2             1      apples         3    1.0            1     oranges
# 3             1     oranges         4    0.8            1      apples
# 4             1     oranges         4    0.8            1  cantaloupe
# 5             1     oranges         4    0.8            1     oranges
# 6             1  cantaloupe         5    2.0            1      apples
# 7             1  cantaloupe         5    2.0            1  cantaloupe
# 8             1  cantaloupe         5    2.0            1     oranges
# 9             2      apples         6    0.9            2      apples
# 10            2      apples         6    0.9            2     oranges
# 11            2     oranges         8    1.2            2      apples
# 12            2     oranges         8    1.2            2     oranges
#
#     quantity  price
# 0          3    1.0
# 1          5    2.0
# 2          4    0.8
# 3          3    1.0
# 4          5    2.0
# 5          4    0.8
# 6          3    1.0
# 7          5    2.0
# 8          4    0.8
# 9          6    0.9
# 10         8    1.2
# 11         6    0.9
# 12         8    1.2
